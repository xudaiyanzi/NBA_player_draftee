# %%
# Dependencies
from bs4 import BeautifulSoup
import requests

import pandas as pd

# %%
# URL of page to be scraped
url = r'https://www.basketball-reference.com/draft/NBA_2018.html'

# %%
# Retrieve page with the requests module
tables = pd.read_html(url) # Returns list of all tables on page
draft_2018_rough = tables[0] # Select table of interest

# %%
draft_2018_rough.to_csv("draft_2018_rough.csv")

# %%
draft_2018_rough_header1 = pd.read_csv('draft_2018_rough.csv', header=[1])

# %%
draft_2018_rough_header1.head(40)
# Out:
#     Unnamed: 0   Rk   Pk   Tm                   Player  \
# 0            0    1    1  PHO            Deandre Ayton
# 1            1    2    2  SAC            Marvin Bagley
# 2            2    3    3  ATL              Luka Doncic
# 3            3    4    4  MEM            Jaren Jackson
# 4            4    5    5  DAL               Trae Young
# 5            5    6    6  ORL            Mohamed Bamba
# 6            6    7    7  CHI           Wendell Carter
# 7            7    8    8  CLE            Collin Sexton
# 8            8    9    9  NYK               Kevin Knox
# 9            9   10   10  PHI            Mikal Bridges
# 10          10   11   11  CHO  Shai Gilgeous-Alexander
# 11          11   12   12  LAC            Miles Bridges
# 12          12   13   13  LAC          Jerome Robinson
# 13          13   14   14  DEN           Michael Porter
# 14          14   15   15  WAS               Troy Brown
# 15          15   16   16  PHO             Zhaire Smith
# ...

# %%
draft_2018_clean = draft_2018_rough_header1.drop(index = [30,31])

# %%
draft_2018_clean.head(40)
# Out:
#     Unnamed: 0  Rk  Pk   Tm                   Player  \
# 0            0   1   1  PHO            Deandre Ayton
# 1            1   2   2  SAC            Marvin Bagley
# 2            2   3   3  ATL              Luka Doncic
# 3            3   4   4  MEM            Jaren Jackson
# 4            4   5   5  DAL               Trae Young
# 5            5   6   6  ORL            Mohamed Bamba
# 6            6   7   7  CHI           Wendell Carter
# 7            7   8   8  CLE            Collin Sexton
# 8            8   9   9  NYK               Kevin Knox
# 9            9  10  10  PHI            Mikal Bridges
# 10          10  11  11  CHO  Shai Gilgeous-Alexander
# 11          11  12  12  LAC            Miles Bridges
# 12          12  13  13  LAC          Jerome Robinson
# 13          13  14  14  DEN           Michael Porter
# 14          14  15  15  WAS               Troy Brown
# 15          15  16  16  PHO             Zhaire Smith
# 16          16  17  17  MIL         Donte DiVincenzo
# ...
